# %%
import pandas as pd
sale=pd.read_csv(r"C:\Users\hp\Documents\prasanna-pandas\Sales.csv")
sale
# Out:
#                     Date   SKU                Product Name        City  Sales
# 0     2023-01-01 0:00:00  F001             Prateek England      Mumbai     93
# 1     2023-01-01 0:00:00  F002               Lucy Phillepe      Mumbai     36
# 2     2023-01-01 0:00:00  F003                    Badlands      Mumbai      7
# 3     2023-01-01 0:00:00  F004                 Allen Dolly      Mumbai     55
# 4     2023-01-01 0:00:00  F005                      Bucchi      Mumbai     41
# ...                  ...   ...                         ...         ...    ...
# 6195  2023-01-30 0:00:00  G001           Crafting Chandlar  Aurangabad     13
# 6196  2023-01-30 0:00:00  G002                  Desi Kurti  Aurangabad     24
# 6197  2023-01-30 0:00:00  G003  Family Cake and Card Combo  Aurangabad     66
# 6198  2023-01-30 0:00:00  G004           Exact Flower Vase  Aurangabad     55
# 6199  2023-01-30 0:00:00  G005          Friends Dinner Set  Aurangabad     59
#
# [6200 rows x 5 columns]

# %%
df_s=sale.groupby('City')['Sales'].sum()
df_s
# Out:
# City
# Aurangabad    35853
# Mumbai        76946
# Nasik         47959
# Pune          43422
# Name: Sales, dtype: int64

# %%
df_s1=sale.groupby(['City','Product Name'])['Sales'].sum()
df_s1
# Out:
# City        Product Name
# Aurangabad  2plus                              407
#             4 states                           777
#             Abibas Football                    757
#             Allen Dolly                        556
#             Amazing CornFlakes                2091
#                                               ...
# Pune        Story of Your Life                 671
#             SureIt Purifier                    562
#             Tata Yellow Label                 1448
#             Yamaka Rex 5000W Mixer Grinder     587
#             Yoga Mattress                      564
# Name: Sales, Length: 200, dtype: int64

# %%
df_s2=pd.pivot_table(sale,values='Sales',index='City',columns='Product Name',aggfunc='sum')
df_s2
# Out:
# Product Name  2plus  4 states  Abibas Football  Allen Dolly  \
# City
# Aurangabad      407       777              757          556
# Mumbai          609      1439              891         1362
# Nasik           365       689              483         1307
# Pune            465       853              813          824
#
# Product Name  Amazing CornFlakes  Badlands  Blessing Atta 10kg pack  Bucchi  \
# City
# Aurangabad                  2091       508                     2492     404
# Mumbai                      3412      1623                     4411    1710
# Nasik                       2532      1607                     2416    1308
# Pune                        1381       856                     1362     838
#
# Product Name  Crafting Chandlar  Descafe Gold Blend coffee  ...  \
# City                                                        ...
# Aurangabad                  966                       1782  ...
# Mumbai                     1753                       3264  ...
# ...

# %%
df_s3=sale.groupby(['SKU','City','Product Name'])['Sales'].sum()
df_s3
# Out:
# SKU   City        Product Name
# B001  Aurangabad  Harry putar       617
#       Mumbai      Harry putar      1331
#       Nasik       Harry putar       613
#       Pune        Harry putar       846
# B002  Aurangabad  4 states          777
#                                    ...
# V004  Pune        LTA Wise City    1244
# V005  Aurangabad  HIFA 2023        1024
#       Mumbai      HIFA 2023        2668
#       Nasik       HIFA 2023         988
#       Pune        HIFA 2023        1186
# Name: Sales, Length: 200, dtype: int64

# %%
#-------------------SKU MASTER----------------

# %%
import pandas as ps
sku=ps.read_csv(r"C:\Users\hp\Documents\prasanna-pandas\SKU MASTER.csv")
sku
# Out:
#       SKU                     Description              Category  Price
# 0    F001                 Prateek England              Fashion    1140
# 1    F002                   Lucy Phillepe              Fashion    2596
# 2    F003                        Badlands              Fashion    1395
# 3    F004                     Allen Dolly              Fashion    2700
# 4    F005                          Bucchi              Fashion    8400
# 5    M001                          Jhaomi               Mobiles  24300
# 6    M002                          Samson               Mobiles  26250
# 7    M003                           Mokia               Mobiles  12150
# 8    M004                        Hotorola               Mobiles  44500
# 9    M005                           2plus               Mobiles  31950
# 10   B001                    Harry putar                  Books   2730
# 11   B002                       4 states                  Books    847
# ...

# %%
sku.Category.unique()
# Out:
# array(['Fashion ', 'Mobiles', 'Books', 'Video Games ', 'Sports / Fitness',
#        'Medicines/Healthcare', 'Kitchen ', 'Household  ', 'Pet Supplies',
#        'Gifting'], dtype=object)

# %%
df_sku1=sku.groupby(['Category'])['Price'].sum()
df_sku1
# Out:
# Category
# Books                     5617
# Fashion                  16231
# Gifting                  14558
# Household                 2886
# Kitchen                  23730
# Medicines/Healthcare     21194
# Mobiles                 139150
# Pet Supplies             15923
# Sports / Fitness         34728
# Video Games               7003
# Name: Price, dtype: int64

# %%
def price_discount(Category,Price):
    if Category=="Books":
        discount=Price*0.10
        after_dis=Price-discount
    elif Category=="Fashion":
        discount=Price*0.30
        after_dis=Price-discount
    elif Category=="Gifting":
        discount=Price*0.40
        after_dis=Price-discount
    elif Category=="Household":
        discount=Price*0.40
        after_dis=Price-discount
    elif Category=="Kitchen":
        discount=Price*0.30
        after_dis=Price-discount
    elif Category=="Medicines/Healthcare":
        discount=Price*0.30
        after_dis=Price-discount
    elif Category=="Mobiles":
        discount=Price*0.30
        after_dis=Price-discount
    elif Category=="Pet Supplies":
        discount=Price*0.20
        after_dis=Price-discount
    elif Category=="Sports / Fitness":
        discount=Price*0.40
        after_dis=Price-discount
    elif Category=="Video Games":
        discount=Price*0.10
        after_dis=Price-discount
    return after_dis

# %%
price_discount("Sports / Fitness",34728)
# Out:
# 20836.8

# %%
data={"Category":['Books','Fashion','Gifting','Household','Kitchen','Medicines/Healthcare','Mobiles','Pet Supplies','Sports / Fitness','Video Games'],
      "Price":[5617,16231,14558,2886,23730,21194,139150,15923,34728,7003],
     "Discount":[5055,11362,8735,1732,16611,14836,97405,12738,2083.8,6302]}
df = ps.DataFrame(data)
df
# Out:
#                Category   Price  Discount
# 0                 Books    5617    5055.0
# 1               Fashion   16231   11362.0
# 2               Gifting   14558    8735.0
# 3             Household    2886    1732.0
# 4               Kitchen   23730   16611.0
# 5  Medicines/Healthcare   21194   14836.0
# 6               Mobiles  139150   97405.0
# 7          Pet Supplies   15923   12738.0
# 8      Sports / Fitness   34728    2083.8
# 9           Video Games    7003    6302.0

# %%
# ---------table-2-----scenario2

# %%
df_sku2=sku.groupby(['Description','Category'])['Price'].sum()
df_sku2
# Out:
# Description                     Category
# 2plus                           Mobiles                 31950
# 4 states                        Books                     847
# Abibas Football                 Sports / Fitness         2850
# Allen Dolly                     Fashion                  2700
# Amazing CornFlakes              Household                 216
# Badlands                        Fashion                  1395
# Blessing Atta 10kg pack         Household                 428
# Bucchi                          Fashion                  8400
# Crafting Chandlar               Gifting                  1680
# Descafe Gold Blend coffee       Household                 690
# Desi Kurti                      Gifting                  2088
# Exact Flower Vase               Gifting                  4200
# Family Cake and Card Combo      Gifting                  1130
# Friends Dinner Set              Gifting                  5460
# ...

# %%
def discount_price(Description,Category,Price):
    if Description=="Allen Dolly":
        if Category=="Fashion":
            discount=Price*0.30
            after_dis=Price-discount
    elif Description=="Bucchi":
        if Category=="Fashion":
            discount=Price*0.30
            after_dis=Price-discount
    elif Description=="Shaktiman Returns":
        if Category=="Books":
            discount=Price*0.30
            after_dis=Price-discount
    elif Description=="Goli's Travel":
        if Category=="Books":
            discount=Price*0.30
            after_dis=Price-discount
    elif Description=="LTA Wise City":
        if Category=="Video Games":
            discount=Price*0.30
            after_dis=Price-discount
    elif Description=="HIFA 2023":
        if Category=="Video Games":
            discount=Price*0.40
            after_dis=Price-discount
    elif Description=="Rocky Gym Set":
        if Category=="Sports / Fitness":
            discount=Price*0.40
            after_dis=Price-discount
    elif Description=="Pyllum Trimmers":
        if Category=="Medicines/Healthcare":
            discount=Price*0.40
            after_dis=Price-discount
    elif Description=="Mr.Clean Dishwasher":
        if Category=="Kitchen":
            discount=Price*0.40
            after_dis=Price-discount
    elif Description=="Blessing Atta 10kg pack":
        if Category=="Household":
            discount=Price*0.40
            after_dis=Price-discount
    elif Description=="Amazing CornFlakes":
        if Category=="Household":
            discount=Price*0.40
            after_dis=Price-discount
    elif Description=="Tata Yellow Label":
        if Category=="Household":
            discount=Price*0.50
            after_dis=Price-discount
    elif Description=="Old Mint Pet Shampoos":
        if Category=="Pet Supplies":
            discount=Price*0.50
            after_dis=Price-discount
    elif Description=="Reflective Dog RainCoat":
        if Category=="Pet Supplies":
            discount=Price*0.50
            after_dis=Price-discount
    elif Description=="Crafting Chandlar":
        if Category=="Gifting":
            discount=Price*0.60
            after_dis=Price-discount
    elif Description=="Desi Kurti":
        if Category=="Gifting":
            discount=Price*0.60
            after_dis=Price-discount
    return after_dis

# %%
discount_price("Reflective Dog RainCoat","Pet Supplies",3776)
# Out:
# 1888.0

# %%
condition={"Description":["Allen Dolly","Bucchi","Shaktiman Returns","Goli's Travel","LTA Wise City","HIFA 2023","Rocky Gym Set","Pyllum Trimmers","Mr.Clean Dishwasher","Blessing Atta 10kg pack","Amazing CornFlakes","Tata Yellow Label","Old Mint Pet Shampoos","Reflective Dog RainCoat","Crafting Chandlar","Desi Kurti"],
      "Category":["Fashion","Fashion","Books","Books","Video Games","Video Games","Sports / Fitness","Medicines/Healthcare","Kitchen","Household","Household","Household","Pet Supplies","Pet Supplies","Gifting","Gifting"],
      "Price":[2700,8400,200,720,2872,2247,12600,1859,15064,428,216,672,1404,3776,1680,2088],
      "price_discount":[1890,5880,140,504,2010.4,1348.12,7560,1115.4,9038.4,256.79,129.6,313.5,702.0,1888.0,672.0,853.2]}
df_stock = ps.DataFrame(condition)
df_stock
# Out:
#                 Description              Category  Price  price_discount
# 0               Allen Dolly               Fashion   2700         1890.00
# 1                    Bucchi               Fashion   8400         5880.00
# 2         Shaktiman Returns                 Books    200          140.00
# 3             Goli's Travel                 Books    720          504.00
# 4             LTA Wise City           Video Games   2872         2010.40
# 5                 HIFA 2023           Video Games   2247         1348.12
# 6             Rocky Gym Set      Sports / Fitness  12600         7560.00
# 7           Pyllum Trimmers  Medicines/Healthcare   1859         1115.40
# 8       Mr.Clean Dishwasher               Kitchen  15064         9038.40
# 9   Blessing Atta 10kg pack             Household    428          256.79
# 10       Amazing CornFlakes             Household    216          129.60
# 11        Tata Yellow Label             Household    672          313.50
# ...

# %%
#-----------SKU Transfer--------

# %%
import pandas as pd
df_sku=pd.read_csv(r"C:\Users\hp\Documents\prasanna-pandas\STOCK TRANSFER_1.csv")
df_sku
# Out:
#       SKU  01-01-2023 00:00  02-01-2023 00:00  03-01-2023 00:00  \
# 0    F001                18                25                21
# 1    F002                20                28                28
# 2    F003                29                26                28
# 3    F004                22                28                20
# 4    F005                19                21                20
# 5    M001                25                19                27
# 6    M002                22                21                27
# 7    M003                26                28                27
# 8    M004                25                18                21
# 9    M005                34                17                24
# 10   B001                70                24                63
# 11   B002                38                66                55
# 12   B003                47                28                74
# 13   B004                22                44                52
# ...

# %%
allDates = pd.date_range('01-01-2023 00:00', '30-01-2023 00:00.2', freq ='W')
allDates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-08', '2023-01-15', '2023-01-22',
#                '2023-01-29'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
series = allDates.to_series()
series
# Out:
# 2023-01-01   2023-01-01
# 2023-01-08   2023-01-08
# 2023-01-15   2023-01-15
# 2023-01-22   2023-01-22
# 2023-01-29   2023-01-29
# Freq: W-SUN, dtype: datetime64[ns]
